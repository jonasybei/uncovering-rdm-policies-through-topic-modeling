# %% [markdown]
# # Imports

# %%
import sys

import optuna
import plotly.express as px
from git_root import git_root
from optuna import visualization
from optuna.trial import TrialState
from optuna.visualization import plot_pareto_front

my_git_root = git_root()
sys.path.append(my_git_root)

# %% [markdown]
# # Loading the relevant study from storage

# %%
storage_url = f"sqlite:////{my_git_root}/final_topic_model_studies.db"

# %%
study_summaries =optuna.get_all_study_summaries(storage_url)

# %%
print("Most Recent Run for Each Study:")
for summary in study_summaries:
    study_name = summary.study_name

    # Load the study
    study = optuna.load_study(study_name=study_name, storage=storage_url)

    # Find the most recent trial based on `datetime_start`
    most_recent_trial = max(
        (trial for trial in study.trials if trial.datetime_start is not None),
        key=lambda trial: trial.datetime_start,
        default=None,
    )

    if most_recent_trial:
        print(f"Study: {study_name}")
        print(f"Most Recent Run: {most_recent_trial.datetime_start}")
        print(f'Number of Trials: {len(study.trials)}')
    else:
        print(f"Study: {study_name}")
        print("No trials have been run yet.\n")
# Out:
# Most Recent Run for Each Study:
# Study: bertopic_double_optimization_v3
# Most Recent Run: 2025-01-28 10:22:40.855067
# Number of Trials: 208
# Study: bertopic_double_optimization_v2
# No trials have been run yet.
#
# Study: LDA_double_optimization_v1
# Most Recent Run: 2025-02-02 09:45:30.064091
# Number of Trials: 517
# Study: bertopic_double_optimization_v1
# Most Recent Run: 2025-02-02 10:17:18.269488
# Number of Trials: 515
# Study: bertopic_double_optimization_pre_processed_dataset_v1
# Most Recent Run: 2025-02-02 09:47:47.540056
# Number of Trials: 604
# Study: visualize_topic_numbers
# Most Recent Run: 2025-02-02 10:16:59.892119
# Number of Trials: 511

# %%
study = optuna.create_study(directions=['maximize', 'maximize'], study_name='bertopic_double_optimization_pre_processed_dataset_v1', storage=storage_url, load_if_exists=True)
# Out:
# [I 2025-02-03 12:54:50,650] Using an existing study with name 'bertopic_double_optimization_pre_processed_dataset_v1' instead of creating a new one.

# %%
study.trials
# Out:
# [FrozenTrial(number=0, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 16, 37, 582040), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 0, 103630), params={'n_neighbors': 39, 'min_dist': 0.9556428757689246, 'min_cluster_size': 75, 'min_samples': 62}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4214, value=None),
#  FrozenTrial(number=1, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 0, 235638), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 15, 3620), params={'n_neighbors': 17, 'min_dist': 0.2403950683025824, 'min_cluster_size': 10, 'min_samples': 88}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4215, value=None),
#  FrozenTrial(number=2, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 15, 357251), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 31, 922538), params={'n_neighbors': 61, 'min_dist': 0.737265320016441, 'min_cluster_size': 6, 'min_samples': 98}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4216, value=None),
#  FrozenTrial(number=3, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 31, 933686), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 48, 888674), params={'n_neighbors': 84, 'min_dist': 0.29110519961044856, 'min_cluster_size': 22, 'min_samples': 22}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4217, value=None),
#  FrozenTrial(number=4, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 48, 901102), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 4, 187220), params={'n_neighbors': 32, 'min_dist': 0.5722807884690141, 'min_cluster_size': 46, 'min_samples': 32}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4218, value=None),
#  FrozenTrial(number=5, state=TrialState.COMPLETE, values=[-0.039305793684878555, 0.5833333333333334], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 4, 198265), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 23, 314526), params={'n_neighbors': 62, 'min_dist': 0.22554447458683766, 'min_cluster_size': 33, 'min_samples': 40}, user_attrs={'num_topics': 12}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4219, value=None),
#  FrozenTrial(number=6, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 23, 326323), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 38, 815830), params={'n_neighbors': 47, 'min_dist': 0.8066583652537123, 'min_cluster_size': 24, 'min_samples': 54}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4220, value=None),
#  FrozenTrial(number=7, state=TrialState.COMPLETE, values=[-0.01099320727377891, 0.496], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 38, 826256), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 57, 902863), params={'n_neighbors': 60, 'min_dist': 0.14180537144799796, 'min_cluster_size': 63, 'min_samples': 21}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4221, value=None),
#  FrozenTrial(number=8, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 57, 914251), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 11, 389995), params={'n_neighbors': 8, 'min_dist': 0.9539969835279999, 'min_cluster_size': 97, 'min_samples': 82}, user_attrs={'num_topics': 1}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4222, value=None),
#  FrozenTrial(number=9, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 11, 401040), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 26, 194081), params={'n_neighbors': 32, 'min_dist': 0.1879049026057455, 'min_cluster_size': 70, 'min_samples': 47}, user_attrs={'num_topics': 8}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4223, value=None),
#  FrozenTrial(number=10, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 26, 204979), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 42, 505336), params={'n_neighbors': 96, 'min_dist': 0.4273549062594681, 'min_cluster_size': 60, 'min_samples': 6}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4224, value=None),
#  FrozenTrial(number=11, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 42, 516079), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 58, 397609), params={'n_neighbors': 68, 'min_dist': 0.13485267996506461, 'min_cluster_size': 44, 'min_samples': 6}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4225, value=None),
#  FrozenTrial(number=12, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 58, 408521), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 14, 241076), params={'n_neighbors': 69, 'min_dist': 0.3508528403108787, 'min_cluster_size': 89, 'min_samples': 29}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4226, value=None),
#  FrozenTrial(number=13, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 14, 251727), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 30, 467091), params={'n_neighbors': 81, 'min_dist': 0.49092064458077006, 'min_cluster_size': 35, 'min_samples': 42}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4227, value=None),
#  FrozenTrial(number=14, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 30, 477968), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 46, 3640), params={'n_neighbors': 56, 'min_dist': 0.11197681827551724, 'min_cluster_size': 61, 'min_samples': 18}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4228, value=None),
#  FrozenTrial(number=15, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 46, 14814), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 1, 888355), params={'n_neighbors': 78, 'min_dist': 0.3167271437508191, 'min_cluster_size': 79, 'min_samples': 67}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4229, value=None),
#  FrozenTrial(number=16, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 1, 899114), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 18, 196293), params={'n_neighbors': 98, 'min_dist': 0.6549267042283847, 'min_cluster_size': 56, 'min_samples': 37}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4230, value=None),
#  FrozenTrial(number=17, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 18, 207300), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 33, 480964), params={'n_neighbors': 48, 'min_dist': 0.1027757103134467, 'min_cluster_size': 40, 'min_samples': 17}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4231, value=None),
#  FrozenTrial(number=18, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 33, 491459), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 48, 12983), params={'n_neighbors': 24, 'min_dist': 0.4051127300235367, 'min_cluster_size': 67, 'min_samples': 26}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4232, value=None),
#  FrozenTrial(number=19, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 48, 23715), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 3, 556399), params={'n_neighbors': 59, 'min_dist': 0.21583879320524268, 'min_cluster_size': 85, 'min_samples': 53}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4233, value=None),
#  FrozenTrial(number=20, state=TrialState.COMPLETE, values=[-0.019624256880170936, 0.6228571428571429], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 3, 567116), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 21, 868051), params={'n_neighbors': 42, 'min_dist': 0.5375246629627751, 'min_cluster_size': 30, 'min_samples': 15}, user_attrs={'num_topics': 14}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4234, value=None),
#  FrozenTrial(number=21, state=TrialState.COMPLETE, values=[-0.02596547542170234, 0.64], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 21, 879432), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 40, 131359), params={'n_neighbors': 46, 'min_dist': 0.824700516524986, 'min_cluster_size': 23, 'min_samples': 12}, user_attrs={'num_topics': 13}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4235, value=None),
#  FrozenTrial(number=22, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 40, 142501), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 55, 247859), params={'n_neighbors': 40, 'min_dist': 0.8331311158121288, 'min_cluster_size': 20, 'min_samples': 14}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4236, value=None),
#  FrozenTrial(number=23, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 55, 258148), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 7, 432374), params={'n_neighbors': 3, 'min_dist': 0.6095105962896565, 'min_cluster_size': 50, 'min_samples': 12}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4237, value=None),
#  FrozenTrial(number=24, state=TrialState.COMPLETE, values=[-0.05560278493954577, 0.5933333333333334], datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 7, 442935), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 25, 757724), params={'n_neighbors': 41, 'min_dist': 0.502933862017341, 'min_cluster_size': 30, 'min_samples': 25}, user_attrs={'num_topics': 12}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4238, value=None),
#  FrozenTrial(number=25, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 25, 768637), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 40, 488409), params={'n_neighbors': 28, 'min_dist': 0.7177317865433761, 'min_cluster_size': 52, 'min_samples': 5}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4239, value=None),
#  FrozenTrial(number=26, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 40, 496937), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 54, 804263), params={'n_neighbors': 18, 'min_dist': 0.44613200670803604, 'min_cluster_size': 16, 'min_samples': 33}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4240, value=None),
#  FrozenTrial(number=27, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 54, 812863), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 10, 457532), params={'n_neighbors': 52, 'min_dist': 0.8652506389463095, 'min_cluster_size': 29, 'min_samples': 69}, user_attrs={'num_topics': 5}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4241, value=None),
#  FrozenTrial(number=28, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 10, 465903), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 26, 520149), params={'n_neighbors': 68, 'min_dist': 0.7010132046256832, 'min_cluster_size': 41, 'min_samples': 13}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4242, value=None),
#  FrozenTrial(number=29, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 26, 531030), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 41, 962392), params={'n_neighbors': 46, 'min_dist': 0.9562024548061296, 'min_cluster_size': 14, 'min_samples': 47}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4243, value=None),
#  FrozenTrial(number=30, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 41, 973422), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 57, 223693), params={'n_neighbors': 38, 'min_dist': 0.5784323210352387, 'min_cluster_size': 67, 'min_samples': 19}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4244, value=None),
#  FrozenTrial(number=31, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 57, 234638), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 13, 14390), params={'n_neighbors': 54, 'min_dist': 0.8842075783165868, 'min_cluster_size': 35, 'min_samples': 10}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4245, value=None),
#  FrozenTrial(number=32, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 13, 25567), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 28, 3899), params={'n_neighbors': 37, 'min_dist': 0.2591847772335185, 'min_cluster_size': 29, 'min_samples': 20}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4246, value=None),
#  FrozenTrial(number=33, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 28, 14424), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 43, 845379), params={'n_neighbors': 63, 'min_dist': 0.1738854447792757, 'min_cluster_size': 6, 'min_samples': 38}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4247, value=None),
#  FrozenTrial(number=34, state=TrialState.COMPLETE, values=[-0.030021901602750468, 0.556], datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 43, 855842), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 2, 773449), params={'n_neighbors': 74, 'min_dist': 0.7841010874586768, 'min_cluster_size': 36, 'min_samples': 23}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4248, value=None),
#  FrozenTrial(number=35, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 2, 784841), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 17, 990273), params={'n_neighbors': 44, 'min_dist': 0.37606169203089906, 'min_cluster_size': 24, 'min_samples': 98}, user_attrs={'num_topics': 5}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4249, value=None),
#  FrozenTrial(number=36, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 18, 1009), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 34, 303856), params={'n_neighbors': 86, 'min_dist': 0.28260254370252785, 'min_cluster_size': 15, 'min_samples': 78}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4250, value=None),
#  FrozenTrial(number=37, state=TrialState.COMPLETE, values=[-0.07352439436648828, 0.691764705882353], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 34, 315085), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 51, 841832), params={'n_neighbors': 20, 'min_dist': 0.5230579161140699, 'min_cluster_size': 10, 'min_samples': 30}, user_attrs={'num_topics': 17}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4251, value=None),
#  FrozenTrial(number=38, state=TrialState.COMPLETE, values=[-0.0531339603552355, 0.6123076923076923], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 51, 853208), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 9, 77422), params={'n_neighbors': 18, 'min_dist': 0.6422747682600507, 'min_cluster_size': 11, 'min_samples': 31}, user_attrs={'num_topics': 13}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4252, value=None),
#  FrozenTrial(number=39, state=TrialState.COMPLETE, values=[-0.05884685243509342, 0.6613333333333333], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 9, 89202), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 27, 179433), params={'n_neighbors': 33, 'min_dist': 0.5271014802755891, 'min_cluster_size': 20, 'min_samples': 25}, user_attrs={'num_topics': 15}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4253, value=None),
#  FrozenTrial(number=40, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 27, 190213), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 42, 164889), params={'n_neighbors': 32, 'min_dist': 0.4677432045811202, 'min_cluster_size': 21, 'min_samples': 11}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4254, value=None),
#  FrozenTrial(number=41, state=TrialState.COMPLETE, values=[-0.07270338873780387, 0.704], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 42, 175990), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 59, 940457), params={'n_neighbors': 24, 'min_dist': 0.6706116933163492, 'min_cluster_size': 7, 'min_samples': 25}, user_attrs={'num_topics': 15}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4255, value=None),
#  FrozenTrial(number=42, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 59, 951432), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 13, 711361), params={'n_neighbors': 12, 'min_dist': 0.7570718481727999, 'min_cluster_size': 6, 'min_samples': 23}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4256, value=None),
#  FrozenTrial(number=43, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 13, 721920), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 28, 693153), params={'n_neighbors': 28, 'min_dist': 0.5579005594535127, 'min_cluster_size': 18, 'min_samples': 14}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4257, value=None),
#  FrozenTrial(number=44, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 28, 701305), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 44, 80618), params={'n_neighbors': 34, 'min_dist': 0.6681351203857588, 'min_cluster_size': 24, 'min_samples': 8}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4258, value=None),
#  FrozenTrial(number=45, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 44, 88785), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 59, 671457), params={'n_neighbors': 49, 'min_dist': 0.9044541694328765, 'min_cluster_size': 48, 'min_samples': 17}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4259, value=None),
#  FrozenTrial(number=46, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 59, 682444), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 14, 525560), params={'n_neighbors': 27, 'min_dist': 0.6003940121327194, 'min_cluster_size': 74, 'min_samples': 27}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4260, value=None),
#  FrozenTrial(number=47, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 14, 536321), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 29, 924935), params={'n_neighbors': 44, 'min_dist': 0.9918798974081383, 'min_cluster_size': 57, 'min_samples': 88}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4261, value=None),
#  FrozenTrial(number=48, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 29, 935658), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 45, 689708), params={'n_neighbors': 58, 'min_dist': 0.765899631824078, 'min_cluster_size': 27, 'min_samples': 45}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4262, value=None),
#  FrozenTrial(number=49, state=TrialState.COMPLETE, values=[-0.05177071766693018, 0.6327272727272727], datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 45, 700786), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 4, 703967), params={'n_neighbors': 64, 'min_dist': 0.537650733441851, 'min_cluster_size': 11, 'min_samples': 33}, user_attrs={'num_topics': 11}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4263, value=None),
#  FrozenTrial(number=50, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 4, 715021), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 20, 203903), params={'n_neighbors': 51, 'min_dist': 0.703440236788853, 'min_cluster_size': 99, 'min_samples': 20}, user_attrs={'num_topics': 5}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4264, value=None),
#  FrozenTrial(number=51, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 20, 214397), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 35, 412070), params={'n_neighbors': 37, 'min_dist': 0.5301872474365679, 'min_cluster_size': 39, 'min_samples': 35}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4265, value=None),
#  FrozenTrial(number=52, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 35, 422705), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 51, 236352), params={'n_neighbors': 62, 'min_dist': 0.8131757819536392, 'min_cluster_size': 12, 'min_samples': 16}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4266, value=None),
#  FrozenTrial(number=53, state=TrialState.COMPLETE, values=[-0.029872129753412847, 0.509090909090909], datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 51, 247252), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 8, 594682), params={'n_neighbors': 22, 'min_dist': 0.3492788500591183, 'min_cluster_size': 63, 'min_samples': 9}, user_attrs={'num_topics': 11}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4267, value=None),
#  FrozenTrial(number=54, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 8, 607712), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 24, 941137), params={'n_neighbors': 93, 'min_dist': 0.6242488149791064, 'min_cluster_size': 31, 'min_samples': 41}, user_attrs={'num_topics': 8}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4268, value=None),
#  FrozenTrial(number=55, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 24, 957119), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 40, 484938), params={'n_neighbors': 43, 'min_dist': 0.14678576366542617, 'min_cluster_size': 33, 'min_samples': 28}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4269, value=None),
#  FrozenTrial(number=56, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 40, 496204), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 54, 161927), params={'n_neighbors': 12, 'min_dist': 0.21834163950244306, 'min_cluster_size': 26, 'min_samples': 22}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4270, value=None),
#  FrozenTrial(number=57, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 54, 172711), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 9, 858476), params={'n_neighbors': 55, 'min_dist': 0.4136680287715583, 'min_cluster_size': 44, 'min_samples': 6}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4271, value=None),
#  FrozenTrial(number=58, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 9, 869401), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 24, 941641), params={'n_neighbors': 34, 'min_dist': 0.46704651138047654, 'min_cluster_size': 18, 'min_samples': 58}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4272, value=None),
#  FrozenTrial(number=59, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 24, 949651), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 40, 948977), params={'n_neighbors': 73, 'min_dist': 0.6730645257951238, 'min_cluster_size': 82, 'min_samples': 15}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4273, value=None),
#  FrozenTrial(number=60, state=TrialState.COMPLETE, values=[-0.04848959475617035, 0.6], datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 40, 959594), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 58, 921962), params={'n_neighbors': 30, 'min_dist': 0.8551186231492618, 'min_cluster_size': 20, 'min_samples': 26}, user_attrs={'num_topics': 12}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4274, value=None),
#  FrozenTrial(number=61, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 58, 933082), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 14, 271290), params={'n_neighbors': 47, 'min_dist': 0.577772436012856, 'min_cluster_size': 55, 'min_samples': 22}, user_attrs={'num_topics': 8}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4275, value=None),
#  FrozenTrial(number=62, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 14, 281984), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 29, 445732), params={'n_neighbors': 41, 'min_dist': 0.13934837175711326, 'min_cluster_size': 71, 'min_samples': 18}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4276, value=None),
#  FrozenTrial(number=63, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 29, 456186), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 44, 977768), params={'n_neighbors': 51, 'min_dist': 0.9136117993376922, 'min_cluster_size': 91, 'min_samples': 11}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4277, value=None),
#  FrozenTrial(number=64, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 44, 988224), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 59, 537252), params={'n_neighbors': 24, 'min_dist': 0.17816986693810233, 'min_cluster_size': 8, 'min_samples': 33}, user_attrs={'num_topics': 2}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4278, value=None),
#  FrozenTrial(number=65, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 59, 548132), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 15, 354990), params={'n_neighbors': 65, 'min_dist': 0.5234278348851061, 'min_cluster_size': 23, 'min_samples': 24}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4279, value=None),
#  FrozenTrial(number=66, state=TrialState.COMPLETE, values=[-0.012385203202129758, 0.544], datetime_start=datetime.datetime(2025, 2, 1, 20, 34, 15, 366087), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 33, 933046), params={'n_neighbors': 57, 'min_dist': 0.7259798973183588, 'min_cluster_size': 38, 'min_samples': 13}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4280, value=None),
#  FrozenTrial(number=67, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 20, 34, 33, 943823), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 49, 637315), params={'n_neighbors': 58, 'min_dist': 0.7262981248939868, 'min_cluster_size': 37, 'min_samples': 8}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=4281, value=None),
# ...
#  FrozenTrial(number=582, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 22, 710311), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 39, 596621), params={'n_neighbors': 84, 'min_dist': 0.7991987203640427, 'min_cluster_size': 5, 'min_samples': 7}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9043, value=None),
#  FrozenTrial(number=583, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 39, 607570), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 55, 349023), params={'n_neighbors': 35, 'min_dist': 0.7474357368405874, 'min_cluster_size': 7, 'min_samples': 9}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9044, value=None),
#  FrozenTrial(number=584, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 55, 359925), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 11, 374665), params={'n_neighbors': 56, 'min_dist': 0.7692443532426843, 'min_cluster_size': 82, 'min_samples': 5}, user_attrs={'num_topics': 7}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9045, value=None),
#  FrozenTrial(number=585, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 11, 385299), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 27, 746288), params={'n_neighbors': 69, 'min_dist': 0.721076439350536, 'min_cluster_size': 10, 'min_samples': 10}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9046, value=None),
#  FrozenTrial(number=586, state=TrialState.COMPLETE, values=[-0.07238166579070152, 0.648], datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 27, 757760), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 46, 999302), params={'n_neighbors': 52, 'min_dist': 0.7793309201343319, 'min_cluster_size': 7, 'min_samples': 34}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9047, value=None),
#  FrozenTrial(number=587, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 47, 10630), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 3, 969515), params={'n_neighbors': 93, 'min_dist': 0.22842572085023927, 'min_cluster_size': 5, 'min_samples': 23}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9048, value=None),
#  FrozenTrial(number=588, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 3, 980326), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 19, 880252), params={'n_neighbors': 39, 'min_dist': 0.4848007487732512, 'min_cluster_size': 9, 'min_samples': 7}, user_attrs={'num_topics': 8}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9049, value=None),
#  FrozenTrial(number=589, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 19, 891327), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 36, 712892), params={'n_neighbors': 88, 'min_dist': 0.7449564710612869, 'min_cluster_size': 7, 'min_samples': 5}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9050, value=None),
#  FrozenTrial(number=590, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 36, 723839), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 50, 978061), params={'n_neighbors': 10, 'min_dist': 0.8115352281517385, 'min_cluster_size': 5, 'min_samples': 81}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9051, value=None),
#  FrozenTrial(number=591, state=TrialState.COMPLETE, values=[-0.06462317222619485, 0.588], datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 50, 988962), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 10, 717400), params={'n_neighbors': 72, 'min_dist': 0.5395849381168252, 'min_cluster_size': 11, 'min_samples': 48}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9052, value=None),
#  FrozenTrial(number=592, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 10, 728436), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 26, 575785), params={'n_neighbors': 51, 'min_dist': 0.7623552292229524, 'min_cluster_size': 55, 'min_samples': 11}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9053, value=None),
#  FrozenTrial(number=593, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 26, 587316), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 40, 523743), params={'n_neighbors': 6, 'min_dist': 0.284330596327721, 'min_cluster_size': 7, 'min_samples': 7}, user_attrs={'num_topics': 85}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9054, value=None),
#  FrozenTrial(number=594, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 40, 535117), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 56, 660935), params={'n_neighbors': 54, 'min_dist': 0.73568757971712, 'min_cluster_size': 5, 'min_samples': 5}, user_attrs={'num_topics': 65}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9055, value=None),
#  FrozenTrial(number=595, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 56, 672048), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 12, 144138), params={'n_neighbors': 33, 'min_dist': 0.7901938179321235, 'min_cluster_size': 77, 'min_samples': 75}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9056, value=None),
#  FrozenTrial(number=596, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 12, 155253), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 28, 325953), params={'n_neighbors': 59, 'min_dist': 0.6114145680683918, 'min_cluster_size': 46, 'min_samples': 51}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9057, value=None),
#  FrozenTrial(number=597, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 28, 337176), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 45, 754524), params={'n_neighbors': 98, 'min_dist': 0.7594329215657075, 'min_cluster_size': 89, 'min_samples': 57}, user_attrs={'num_topics': 3}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9058, value=None),
#  FrozenTrial(number=598, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 45, 763016), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 1, 533506), params={'n_neighbors': 30, 'min_dist': 0.9750474353274554, 'min_cluster_size': 9, 'min_samples': 62}, user_attrs={'num_topics': 6}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9059, value=None),
#  FrozenTrial(number=599, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 57, 1, 544758), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 16, 860201), params={'n_neighbors': 24, 'min_dist': 0.841120375866462, 'min_cluster_size': 73, 'min_samples': 7}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9060, value=None),
#  FrozenTrial(number=600, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 57, 16, 871507), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 33, 247766), params={'n_neighbors': 77, 'min_dist': 0.37315343224065434, 'min_cluster_size': 43, 'min_samples': 68}, user_attrs={'num_topics': 8}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9061, value=None),
#  FrozenTrial(number=601, state=TrialState.FAIL, values=None, datetime_start=datetime.datetime(2025, 2, 1, 22, 57, 33, 258957), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 39, 483567), params={'n_neighbors': 49, 'min_dist': 0.779392275030523, 'min_cluster_size': 7, 'min_samples': 9}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=9062, value=None),
#  FrozenTrial(number=602, state=TrialState.PRUNED, values=None, datetime_start=datetime.datetime(2025, 2, 2, 9, 47, 24, 580638), datetime_complete=datetime.datetime(2025, 2, 2, 9, 47, 47, 407512), params={'n_neighbors': 49, 'min_dist': 0.7780343289415684, 'min_cluster_size': 7, 'min_samples': 5}, user_attrs={'num_topics': 9}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=10892, value=None),
#  FrozenTrial(number=603, state=TrialState.FAIL, values=None, datetime_start=datetime.datetime(2025, 2, 2, 9, 47, 47, 540056), datetime_complete=datetime.datetime(2025, 2, 2, 9, 48, 3, 429680), params={'n_neighbors': 38, 'min_dist': 0.7212223662122306, 'min_cluster_size': 5, 'min_samples': 9}, user_attrs={'num_topics': 4}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=11492, value=None)]

# %%
fig = plot_pareto_front(study, target_names=['Coherence', 'Diversity'], include_dominated_trials=False)
fig.update_layout(width=500, height=500, yaxis=dict(scaleanchor="x", scaleratio=1),xaxis=dict(scaleanchor="y", scaleratio=1))
# Out:
# <div>                            <div id="cfa394c8-4a78-4535-9398-0f6bbea6b5c2" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfa394c8-4a78-4535-9398-0f6bbea6b5c2")) {                    Plotly.newPlot(                        "cfa394c8-4a78-4535-9398-0f6bbea6b5c2",                        [{"hovertemplate":"%{text}\u003cextra\u003eTrial\u003c\u002fextra\u003e","marker":{"color":[],"colorbar":{"title":{"text":"Trial"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"line":{"color":"Grey","width":0.5}},"mode":"markers","showlegend":false,"text":[],"x":[],"y":[],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003eBest Trial\u003c\u002fextra\u003e","marker":{"color":[373,384,438],"colorbar":{"title":{"text":"Best Trial"},"x":1,"xpad":40},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"line":{"color":"Grey","width":0.5}},"mode":"markers","showlegend":false,"text":["{\u003cbr\u003e  \"number\": 373,\u003cbr\u003e  \"values\": [\u003cbr\u003e    0.170508518754345,\u003cbr\u003e    0.8676923076923077\u003cbr\u003e  ],\u003cbr\u003e  \"params\": {\u003cbr\u003e    \"n_neighbors\": 51,\u003cbr\u003e    \"min_dist\": 0.7604655010805205,\u003cbr\u003e    \"min_cluster_size\": 5,\u003cbr\u003e    \"min_samples\": 5\u003cbr\u003e  },\u003cbr\u003e  \"user_attrs\": {\u003cbr\u003e    \"num_topics\": 13\u003cbr\u003e  }\u003cbr\u003e}","{\u003cbr\u003e  \"number\": 384,\u003cbr\u003e  \"values\": [\u003cbr\u003e    0.22037868694636017,\u003cbr\u003e    0.84\u003cbr\u003e  ],\u003cbr\u003e  \"params\": {\u003cbr\u003e    \"n_neighbors\": 52,\u003cbr\u003e    \"min_dist\": 0.7654024396138743,\u003cbr\u003e    \"min_cluster_size\": 5,\u003cbr\u003e    \"min_samples\": 5\u003cbr\u003e  },\u003cbr\u003e  \"user_attrs\": {\u003cbr\u003e    \"num_topics\": 11\u003cbr\u003e  }\u003cbr\u003e}","{\u003cbr\u003e  \"number\": 438,\u003cbr\u003e  \"values\": [\u003cbr\u003e    0.08667008067860961,\u003cbr\u003e    0.928\u003cbr\u003e  ],\u003cbr\u003e  \"params\": {\u003cbr\u003e    \"n_neighbors\": 100,\u003cbr\u003e    \"min_dist\": 0.5355763362518458,\u003cbr\u003e    \"min_cluster_size\": 8,\u003cbr\u003e    \"min_samples\": 5\u003cbr\u003e  },\u003cbr\u003e  \"user_attrs\": {\u003cbr\u003e    \"num_topics\": 10\u003cbr\u003e  }\u003cbr\u003e}"],"x":[0.170508518754345,0.22037868694636017,0.08667008067860961],"y":[0.8676923076923077,0.84,0.928],"type":"scatter"}],                        {"title":{"text":"Pareto-front Plot"},"xaxis":{"title":{"text":"Coherence"},"scaleanchor":"y","scaleratio":1},"yaxis":{"title":{"text":"Diversity"},"scaleanchor":"x","scaleratio":1},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed795 ...

# %%
fig = visualization.plot_contour(study, target_name = 'coherence', target=lambda t: (t.values[0]))
fig.update_layout(width=2500, height=2500, template='plotly')
fig.write_html(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_coherence_contour.html")
fig.write_image(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_coherence_contour.pdf")

# %%
fig = visualization.plot_contour(study, target_name = 'diversity', target=lambda t: (t.values[1]))
fig.update_layout(width=2500, height=2500, template='plotly')
fig.write_html(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_diversity_contour.html")
fig.write_image(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_diversity_contour.pdf")

# %%
# Delete the study if it exists and create a new study
optuna.delete_study(storage=storage_url, study_name='visualize_topic_numbers')
visualize_topic_numbers_study = optuna.create_study(
    direction='maximize',
    study_name='visualize_topic_numbers',
    storage=storage_url,
    load_if_exists=True
)

# Assume `study` is defined; replace this with your actual study object
my_trials = []

for index, trial in enumerate(study.trials):
    if 'num_topics' in trial.user_attrs:
        frozen_trial = optuna.trial.FrozenTrial(
            number=index,
            state=TrialState.COMPLETE,
            value=trial.user_attrs['num_topics'],
            datetime_start=trial.datetime_start,
            datetime_complete=trial.datetime_complete,
            params=trial.params,
            distributions=trial.distributions,
            user_attrs= {},
            system_attrs=trial.system_attrs,
            intermediate_values=trial.intermediate_values,
            trial_id=None
        )

        print(frozen_trial)
        my_trials.append(frozen_trial)

# Add trials to the new study
visualize_topic_numbers_study.add_trials(my_trials)
# Out:
# [I 2025-02-03 12:54:55,757] A new study created in RDB with name: visualize_topic_numbers
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 16, 37, 582040), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 0, 103630), params={'n_neighbors': 39, 'min_dist': 0.9556428757689246, 'min_cluster_size': 75, 'min_samples': 62}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=1, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 0, 235638), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 15, 3620), params={'n_neighbors': 17, 'min_dist': 0.2403950683025824, 'min_cluster_size': 10, 'min_samples': 88}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=2, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 15, 357251), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 31, 922538), params={'n_neighbors': 61, 'min_dist': 0.737265320016441, 'min_cluster_size': 6, 'min_samples': 98}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=3, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 31, 933686), datetime_complete=datetime.datetime(2025, 2, 1, 20, 17, 48, 888674), params={'n_neighbors': 84, 'min_dist': 0.29110519961044856, 'min_cluster_size': 22, 'min_samples': 22}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=4, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 17, 48, 901102), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 4, 187220), params={'n_neighbors': 32, 'min_dist': 0.5722807884690141, 'min_cluster_size': 46, 'min_samples': 32}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=5, state=TrialState.COMPLETE, values=[12], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 4, 198265), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 23, 314526), params={'n_neighbors': 62, 'min_dist': 0.22554447458683766, 'min_cluster_size': 33, 'min_samples': 40}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=6, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 23, 326323), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 38, 815830), params={'n_neighbors': 47, 'min_dist': 0.8066583652537123, 'min_cluster_size': 24, 'min_samples': 54}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=7, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 38, 826256), datetime_complete=datetime.datetime(2025, 2, 1, 20, 18, 57, 902863), params={'n_neighbors': 60, 'min_dist': 0.14180537144799796, 'min_cluster_size': 63, 'min_samples': 21}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=8, state=TrialState.COMPLETE, values=[1], datetime_start=datetime.datetime(2025, 2, 1, 20, 18, 57, 914251), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 11, 389995), params={'n_neighbors': 8, 'min_dist': 0.9539969835279999, 'min_cluster_size': 97, 'min_samples': 82}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=9, state=TrialState.COMPLETE, values=[8], datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 11, 401040), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 26, 194081), params={'n_neighbors': 32, 'min_dist': 0.1879049026057455, 'min_cluster_size': 70, 'min_samples': 47}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=10, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 26, 204979), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 42, 505336), params={'n_neighbors': 96, 'min_dist': 0.4273549062594681, 'min_cluster_size': 60, 'min_samples': 6}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=11, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 42, 516079), datetime_complete=datetime.datetime(2025, 2, 1, 20, 19, 58, 397609), params={'n_neighbors': 68, 'min_dist': 0.13485267996506461, 'min_cluster_size': 44, 'min_samples': 6}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=12, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 19, 58, 408521), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 14, 241076), params={'n_neighbors': 69, 'min_dist': 0.3508528403108787, 'min_cluster_size': 89, 'min_samples': 29}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=13, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 14, 251727), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 30, 467091), params={'n_neighbors': 81, 'min_dist': 0.49092064458077006, 'min_cluster_size': 35, 'min_samples': 42}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=14, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 30, 477968), datetime_complete=datetime.datetime(2025, 2, 1, 20, 20, 46, 3640), params={'n_neighbors': 56, 'min_dist': 0.11197681827551724, 'min_cluster_size': 61, 'min_samples': 18}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=15, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 20, 46, 14814), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 1, 888355), params={'n_neighbors': 78, 'min_dist': 0.3167271437508191, 'min_cluster_size': 79, 'min_samples': 67}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=16, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 1, 899114), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 18, 196293), params={'n_neighbors': 98, 'min_dist': 0.6549267042283847, 'min_cluster_size': 56, 'min_samples': 37}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=17, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 18, 207300), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 33, 480964), params={'n_neighbors': 48, 'min_dist': 0.1027757103134467, 'min_cluster_size': 40, 'min_samples': 17}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=18, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 33, 491459), datetime_complete=datetime.datetime(2025, 2, 1, 20, 21, 48, 12983), params={'n_neighbors': 24, 'min_dist': 0.4051127300235367, 'min_cluster_size': 67, 'min_samples': 26}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=19, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 21, 48, 23715), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 3, 556399), params={'n_neighbors': 59, 'min_dist': 0.21583879320524268, 'min_cluster_size': 85, 'min_samples': 53}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=20, state=TrialState.COMPLETE, values=[14], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 3, 567116), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 21, 868051), params={'n_neighbors': 42, 'min_dist': 0.5375246629627751, 'min_cluster_size': 30, 'min_samples': 15}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=21, state=TrialState.COMPLETE, values=[13], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 21, 879432), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 40, 131359), params={'n_neighbors': 46, 'min_dist': 0.824700516524986, 'min_cluster_size': 23, 'min_samples': 12}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=22, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 40, 142501), datetime_complete=datetime.datetime(2025, 2, 1, 20, 22, 55, 247859), params={'n_neighbors': 40, 'min_dist': 0.8331311158121288, 'min_cluster_size': 20, 'min_samples': 14}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=23, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 22, 55, 258148), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 7, 432374), params={'n_neighbors': 3, 'min_dist': 0.6095105962896565, 'min_cluster_size': 50, 'min_samples': 12}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=24, state=TrialState.COMPLETE, values=[12], datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 7, 442935), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 25, 757724), params={'n_neighbors': 41, 'min_dist': 0.502933862017341, 'min_cluster_size': 30, 'min_samples': 25}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=25, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 25, 768637), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 40, 488409), params={'n_neighbors': 28, 'min_dist': 0.7177317865433761, 'min_cluster_size': 52, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=26, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 40, 496937), datetime_complete=datetime.datetime(2025, 2, 1, 20, 23, 54, 804263), params={'n_neighbors': 18, 'min_dist': 0.44613200670803604, 'min_cluster_size': 16, 'min_samples': 33}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=27, state=TrialState.COMPLETE, values=[5], datetime_start=datetime.datetime(2025, 2, 1, 20, 23, 54, 812863), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 10, 457532), params={'n_neighbors': 52, 'min_dist': 0.8652506389463095, 'min_cluster_size': 29, 'min_samples': 69}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=28, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 10, 465903), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 26, 520149), params={'n_neighbors': 68, 'min_dist': 0.7010132046256832, 'min_cluster_size': 41, 'min_samples': 13}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=29, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 26, 531030), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 41, 962392), params={'n_neighbors': 46, 'min_dist': 0.9562024548061296, 'min_cluster_size': 14, 'min_samples': 47}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=30, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 41, 973422), datetime_complete=datetime.datetime(2025, 2, 1, 20, 24, 57, 223693), params={'n_neighbors': 38, 'min_dist': 0.5784323210352387, 'min_cluster_size': 67, 'min_samples': 19}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=31, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 24, 57, 234638), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 13, 14390), params={'n_neighbors': 54, 'min_dist': 0.8842075783165868, 'min_cluster_size': 35, 'min_samples': 10}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=32, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 13, 25567), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 28, 3899), params={'n_neighbors': 37, 'min_dist': 0.2591847772335185, 'min_cluster_size': 29, 'min_samples': 20}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=33, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 28, 14424), datetime_complete=datetime.datetime(2025, 2, 1, 20, 25, 43, 845379), params={'n_neighbors': 63, 'min_dist': 0.1738854447792757, 'min_cluster_size': 6, 'min_samples': 38}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=34, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 20, 25, 43, 855842), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 2, 773449), params={'n_neighbors': 74, 'min_dist': 0.7841010874586768, 'min_cluster_size': 36, 'min_samples': 23}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=35, state=TrialState.COMPLETE, values=[5], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 2, 784841), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 17, 990273), params={'n_neighbors': 44, 'min_dist': 0.37606169203089906, 'min_cluster_size': 24, 'min_samples': 98}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=36, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 18, 1009), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 34, 303856), params={'n_neighbors': 86, 'min_dist': 0.28260254370252785, 'min_cluster_size': 15, 'min_samples': 78}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=37, state=TrialState.COMPLETE, values=[17], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 34, 315085), datetime_complete=datetime.datetime(2025, 2, 1, 20, 26, 51, 841832), params={'n_neighbors': 20, 'min_dist': 0.5230579161140699, 'min_cluster_size': 10, 'min_samples': 30}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=38, state=TrialState.COMPLETE, values=[13], datetime_start=datetime.datetime(2025, 2, 1, 20, 26, 51, 853208), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 9, 77422), params={'n_neighbors': 18, 'min_dist': 0.6422747682600507, 'min_cluster_size': 11, 'min_samples': 31}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=39, state=TrialState.COMPLETE, values=[15], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 9, 89202), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 27, 179433), params={'n_neighbors': 33, 'min_dist': 0.5271014802755891, 'min_cluster_size': 20, 'min_samples': 25}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=40, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 27, 190213), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 42, 164889), params={'n_neighbors': 32, 'min_dist': 0.4677432045811202, 'min_cluster_size': 21, 'min_samples': 11}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=41, state=TrialState.COMPLETE, values=[15], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 42, 175990), datetime_complete=datetime.datetime(2025, 2, 1, 20, 27, 59, 940457), params={'n_neighbors': 24, 'min_dist': 0.6706116933163492, 'min_cluster_size': 7, 'min_samples': 25}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=42, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 27, 59, 951432), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 13, 711361), params={'n_neighbors': 12, 'min_dist': 0.7570718481727999, 'min_cluster_size': 6, 'min_samples': 23}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=43, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 13, 721920), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 28, 693153), params={'n_neighbors': 28, 'min_dist': 0.5579005594535127, 'min_cluster_size': 18, 'min_samples': 14}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=44, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 28, 701305), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 44, 80618), params={'n_neighbors': 34, 'min_dist': 0.6681351203857588, 'min_cluster_size': 24, 'min_samples': 8}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=45, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 44, 88785), datetime_complete=datetime.datetime(2025, 2, 1, 20, 28, 59, 671457), params={'n_neighbors': 49, 'min_dist': 0.9044541694328765, 'min_cluster_size': 48, 'min_samples': 17}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=46, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 28, 59, 682444), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 14, 525560), params={'n_neighbors': 27, 'min_dist': 0.6003940121327194, 'min_cluster_size': 74, 'min_samples': 27}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=47, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 14, 536321), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 29, 924935), params={'n_neighbors': 44, 'min_dist': 0.9918798974081383, 'min_cluster_size': 57, 'min_samples': 88}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=48, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 29, 935658), datetime_complete=datetime.datetime(2025, 2, 1, 20, 29, 45, 689708), params={'n_neighbors': 58, 'min_dist': 0.765899631824078, 'min_cluster_size': 27, 'min_samples': 45}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=49, state=TrialState.COMPLETE, values=[11], datetime_start=datetime.datetime(2025, 2, 1, 20, 29, 45, 700786), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 4, 703967), params={'n_neighbors': 64, 'min_dist': 0.537650733441851, 'min_cluster_size': 11, 'min_samples': 33}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=50, state=TrialState.COMPLETE, values=[5], datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 4, 715021), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 20, 203903), params={'n_neighbors': 51, 'min_dist': 0.703440236788853, 'min_cluster_size': 99, 'min_samples': 20}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=51, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 20, 214397), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 35, 412070), params={'n_neighbors': 37, 'min_dist': 0.5301872474365679, 'min_cluster_size': 39, 'min_samples': 35}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=52, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 35, 422705), datetime_complete=datetime.datetime(2025, 2, 1, 20, 30, 51, 236352), params={'n_neighbors': 62, 'min_dist': 0.8131757819536392, 'min_cluster_size': 12, 'min_samples': 16}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=53, state=TrialState.COMPLETE, values=[11], datetime_start=datetime.datetime(2025, 2, 1, 20, 30, 51, 247252), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 8, 594682), params={'n_neighbors': 22, 'min_dist': 0.3492788500591183, 'min_cluster_size': 63, 'min_samples': 9}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=54, state=TrialState.COMPLETE, values=[8], datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 8, 607712), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 24, 941137), params={'n_neighbors': 93, 'min_dist': 0.6242488149791064, 'min_cluster_size': 31, 'min_samples': 41}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=55, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 24, 957119), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 40, 484938), params={'n_neighbors': 43, 'min_dist': 0.14678576366542617, 'min_cluster_size': 33, 'min_samples': 28}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=56, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 40, 496204), datetime_complete=datetime.datetime(2025, 2, 1, 20, 31, 54, 161927), params={'n_neighbors': 12, 'min_dist': 0.21834163950244306, 'min_cluster_size': 26, 'min_samples': 22}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=57, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 31, 54, 172711), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 9, 858476), params={'n_neighbors': 55, 'min_dist': 0.4136680287715583, 'min_cluster_size': 44, 'min_samples': 6}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=58, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 9, 869401), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 24, 941641), params={'n_neighbors': 34, 'min_dist': 0.46704651138047654, 'min_cluster_size': 18, 'min_samples': 58}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=59, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 24, 949651), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 40, 948977), params={'n_neighbors': 73, 'min_dist': 0.6730645257951238, 'min_cluster_size': 82, 'min_samples': 15}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=60, state=TrialState.COMPLETE, values=[12], datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 40, 959594), datetime_complete=datetime.datetime(2025, 2, 1, 20, 32, 58, 921962), params={'n_neighbors': 30, 'min_dist': 0.8551186231492618, 'min_cluster_size': 20, 'min_samples': 26}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=61, state=TrialState.COMPLETE, values=[8], datetime_start=datetime.datetime(2025, 2, 1, 20, 32, 58, 933082), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 14, 271290), params={'n_neighbors': 47, 'min_dist': 0.577772436012856, 'min_cluster_size': 55, 'min_samples': 22}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=62, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 14, 281984), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 29, 445732), params={'n_neighbors': 41, 'min_dist': 0.13934837175711326, 'min_cluster_size': 71, 'min_samples': 18}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=63, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 29, 456186), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 44, 977768), params={'n_neighbors': 51, 'min_dist': 0.9136117993376922, 'min_cluster_size': 91, 'min_samples': 11}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=64, state=TrialState.COMPLETE, values=[2], datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 44, 988224), datetime_complete=datetime.datetime(2025, 2, 1, 20, 33, 59, 537252), params={'n_neighbors': 24, 'min_dist': 0.17816986693810233, 'min_cluster_size': 8, 'min_samples': 33}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=65, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 33, 59, 548132), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 15, 354990), params={'n_neighbors': 65, 'min_dist': 0.5234278348851061, 'min_cluster_size': 23, 'min_samples': 24}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=66, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 20, 34, 15, 366087), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 33, 933046), params={'n_neighbors': 57, 'min_dist': 0.7259798973183588, 'min_cluster_size': 38, 'min_samples': 13}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=67, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 34, 33, 943823), datetime_complete=datetime.datetime(2025, 2, 1, 20, 34, 49, 637315), params={'n_neighbors': 58, 'min_dist': 0.7262981248939868, 'min_cluster_size': 37, 'min_samples': 8}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=68, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 20, 34, 49, 645436), datetime_complete=datetime.datetime(2025, 2, 1, 20, 35, 5, 60690), params={'n_neighbors': 39, 'min_dist': 0.8011031359469194, 'min_cluster_size': 32, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=69, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 20, 35, 5, 68847), datetime_complete=datetime.datetime(2025, 2, 1, 20, 35, 23, 372550), params={'n_neighbors': 34, 'min_dist': 0.7483336062288463, 'min_cluster_size': 43, 'min_samples': 13}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# ...
# FrozenTrial(number=580, state=TrialState.COMPLETE, values=[5], datetime_start=datetime.datetime(2025, 2, 1, 22, 51, 49, 599951), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 6, 15940), params={'n_neighbors': 62, 'min_dist': 0.7590851779406473, 'min_cluster_size': 13, 'min_samples': 96}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=581, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 6, 26737), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 22, 699339), params={'n_neighbors': 74, 'min_dist': 0.7822889207525336, 'min_cluster_size': 8, 'min_samples': 36}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=582, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 22, 710311), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 39, 596621), params={'n_neighbors': 84, 'min_dist': 0.7991987203640427, 'min_cluster_size': 5, 'min_samples': 7}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=583, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 39, 607570), datetime_complete=datetime.datetime(2025, 2, 1, 22, 52, 55, 349023), params={'n_neighbors': 35, 'min_dist': 0.7474357368405874, 'min_cluster_size': 7, 'min_samples': 9}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=584, state=TrialState.COMPLETE, values=[7], datetime_start=datetime.datetime(2025, 2, 1, 22, 52, 55, 359925), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 11, 374665), params={'n_neighbors': 56, 'min_dist': 0.7692443532426843, 'min_cluster_size': 82, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=585, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 11, 385299), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 27, 746288), params={'n_neighbors': 69, 'min_dist': 0.721076439350536, 'min_cluster_size': 10, 'min_samples': 10}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=586, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 27, 757760), datetime_complete=datetime.datetime(2025, 2, 1, 22, 53, 46, 999302), params={'n_neighbors': 52, 'min_dist': 0.7793309201343319, 'min_cluster_size': 7, 'min_samples': 34}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=587, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 22, 53, 47, 10630), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 3, 969515), params={'n_neighbors': 93, 'min_dist': 0.22842572085023927, 'min_cluster_size': 5, 'min_samples': 23}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=588, state=TrialState.COMPLETE, values=[8], datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 3, 980326), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 19, 880252), params={'n_neighbors': 39, 'min_dist': 0.4848007487732512, 'min_cluster_size': 9, 'min_samples': 7}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=589, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 19, 891327), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 36, 712892), params={'n_neighbors': 88, 'min_dist': 0.7449564710612869, 'min_cluster_size': 7, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=590, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 36, 723839), datetime_complete=datetime.datetime(2025, 2, 1, 22, 54, 50, 978061), params={'n_neighbors': 10, 'min_dist': 0.8115352281517385, 'min_cluster_size': 5, 'min_samples': 81}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=591, state=TrialState.COMPLETE, values=[10], datetime_start=datetime.datetime(2025, 2, 1, 22, 54, 50, 988962), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 10, 717400), params={'n_neighbors': 72, 'min_dist': 0.5395849381168252, 'min_cluster_size': 11, 'min_samples': 48}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=592, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 10, 728436), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 26, 575785), params={'n_neighbors': 51, 'min_dist': 0.7623552292229524, 'min_cluster_size': 55, 'min_samples': 11}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=593, state=TrialState.COMPLETE, values=[85], datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 26, 587316), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 40, 523743), params={'n_neighbors': 6, 'min_dist': 0.284330596327721, 'min_cluster_size': 7, 'min_samples': 7}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=594, state=TrialState.COMPLETE, values=[65], datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 40, 535117), datetime_complete=datetime.datetime(2025, 2, 1, 22, 55, 56, 660935), params={'n_neighbors': 54, 'min_dist': 0.73568757971712, 'min_cluster_size': 5, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=595, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 22, 55, 56, 672048), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 12, 144138), params={'n_neighbors': 33, 'min_dist': 0.7901938179321235, 'min_cluster_size': 77, 'min_samples': 75}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=596, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 12, 155253), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 28, 325953), params={'n_neighbors': 59, 'min_dist': 0.6114145680683918, 'min_cluster_size': 46, 'min_samples': 51}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=597, state=TrialState.COMPLETE, values=[3], datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 28, 337176), datetime_complete=datetime.datetime(2025, 2, 1, 22, 56, 45, 754524), params={'n_neighbors': 98, 'min_dist': 0.7594329215657075, 'min_cluster_size': 89, 'min_samples': 57}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=598, state=TrialState.COMPLETE, values=[6], datetime_start=datetime.datetime(2025, 2, 1, 22, 56, 45, 763016), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 1, 533506), params={'n_neighbors': 30, 'min_dist': 0.9750474353274554, 'min_cluster_size': 9, 'min_samples': 62}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=599, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 1, 22, 57, 1, 544758), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 16, 860201), params={'n_neighbors': 24, 'min_dist': 0.841120375866462, 'min_cluster_size': 73, 'min_samples': 7}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=600, state=TrialState.COMPLETE, values=[8], datetime_start=datetime.datetime(2025, 2, 1, 22, 57, 16, 871507), datetime_complete=datetime.datetime(2025, 2, 1, 22, 57, 33, 247766), params={'n_neighbors': 77, 'min_dist': 0.37315343224065434, 'min_cluster_size': 43, 'min_samples': 68}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=602, state=TrialState.COMPLETE, values=[9], datetime_start=datetime.datetime(2025, 2, 2, 9, 47, 24, 580638), datetime_complete=datetime.datetime(2025, 2, 2, 9, 47, 47, 407512), params={'n_neighbors': 49, 'min_dist': 0.7780343289415684, 'min_cluster_size': 7, 'min_samples': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)
# FrozenTrial(number=603, state=TrialState.COMPLETE, values=[4], datetime_start=datetime.datetime(2025, 2, 2, 9, 47, 47, 540056), datetime_complete=datetime.datetime(2025, 2, 2, 9, 48, 3, 429680), params={'n_neighbors': 38, 'min_dist': 0.7212223662122306, 'min_cluster_size': 5, 'min_samples': 9}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=None, value=None)

# %%
fig = visualization.plot_contour(visualize_topic_numbers_study, target_name = 'Number of Topics')
fig.update_layout(width=2500, height=2500, template='plotly')
fig.write_html(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_num_topics_contour.html")
fig.write_image(f"{my_git_root}/final_notebooks/images/contour_plots/bertopic_pre_processed_num_topics_contour.pdf")

# %%
num_clusters = []
coherences = []
diversities = []

for trial in study.trials:
    if trial.values is not None:
        num_clusters.append(trial.user_attrs['num_topics'])
        coherences.append(trial.values[0])
        diversities.append(trial.values[1])

# %%
fig = px.scatter(x=num_clusters, y=coherences, template='plotly_white')
fig.update_layout(xaxis_title="Number of Clusters", yaxis_title="Coherence Score")
fig.write_image(f'{my_git_root}/notebooks/images/bertopic_pre_processed_coherences.pdf')

# %%
fig = px.scatter(x=num_clusters, y=diversities, template='plotly_white')
fig.update_layout(xaxis_title="Number of Clusters", yaxis_title="Diversity Score")
fig.write_image(f'{my_git_root}/notebooks/images/bertopic_pre_processed_diversities.pdf')

# %%
def calculate_harmonic_mean(coherence, diversity):
    coherence_normalized = (coherence+ 1) / 2
    harmonic_mean = 2 * (coherence_normalized*diversity) / (coherence_normalized+diversity)
    return harmonic_mean

# %%
def evaluate_trial(trial, measurement):
    if measurement == 'coherence':
        return trial.values[0]
    elif measurement == 'diversity':
        return trial.values[1]
    elif measurement == 'harmonic_mean':
        return calculate_harmonic_mean(trial.values[0], trial.values[1])
    else:
        raise ValueError(f"Measurement {measurement} not recognized. Must be 'coherence', 'diversity' or 'harmonic_mean'.")

# %%
def get_max_value(trials, measurement):
    max_value = -1
    max_trial = None
    for trial in trials:
        if trial.values is not None:
            value = evaluate_trial(trial, measurement)
            if value > max_value:
                max_value = value
                max_trial = trial

    return max_value, max_trial

# %%
max_coherence, max_coherence_trial = get_max_value(study.trials, 'coherence')
max_coherence_harmonic_mean = calculate_harmonic_mean(max_coherence_trial.values[0], max_coherence_trial.values[1])

print(f'max_coherence: {max_coherence}\n')
print(f'max_coherence_trial: {max_coherence_trial}\n')
print(f'harmonic_mean: {max_coherence_harmonic_mean}\n')
# Out:
# max_coherence: 0.22037868694636017
#
# max_coherence_trial: FrozenTrial(number=384, state=TrialState.COMPLETE, values=[0.22037868694636017, 0.84], datetime_start=datetime.datetime(2025, 2, 1, 21, 58, 33, 220694), datetime_complete=datetime.datetime(2025, 2, 1, 21, 58, 51, 597310), params={'n_neighbors': 52, 'min_dist': 0.7654024396138743, 'min_cluster_size': 5, 'min_samples': 5}, user_attrs={'num_topics': 11}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=7377, value=None)
#
# harmonic_mean: 0.706885691615828

# %%
max_diversity, max_diversity_trial = get_max_value(study.trials, 'diversity')
max_diversity_harmonic_mean = calculate_harmonic_mean(max_diversity_trial.values[0], max_diversity_trial.values[1])

print(f'max_diversity: {max_diversity}\n')
print(f'max_diversity_trial: {max_diversity_trial}\n')
print(f'harmonic_mean: {max_diversity_harmonic_mean}')
# Out:
# max_diversity: 0.928
#
# max_diversity_trial: FrozenTrial(number=438, state=TrialState.COMPLETE, values=[0.08667008067860961, 0.928], datetime_start=datetime.datetime(2025, 2, 1, 22, 13, 18, 619415), datetime_complete=datetime.datetime(2025, 2, 1, 22, 13, 37, 870069), params={'n_neighbors': 100, 'min_dist': 0.5355763362518458, 'min_cluster_size': 8, 'min_samples': 5}, user_attrs={'num_topics': 10}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=7845, value=None)
#
# harmonic_mean: 0.6853842307984425

# %%
max_harmonic_mean, max_harmonic_mean_trial = get_max_value(study.trials, 'harmonic_mean')
print(f'max_harmonic_mean: {max_harmonic_mean}\n')
print(f'max_harmonic_mean_trial: {max_harmonic_mean_trial}')
# Out:
# max_harmonic_mean: 0.706885691615828
#
# max_harmonic_mean_trial: FrozenTrial(number=384, state=TrialState.COMPLETE, values=[0.22037868694636017, 0.84], datetime_start=datetime.datetime(2025, 2, 1, 21, 58, 33, 220694), datetime_complete=datetime.datetime(2025, 2, 1, 21, 58, 51, 597310), params={'n_neighbors': 52, 'min_dist': 0.7654024396138743, 'min_cluster_size': 5, 'min_samples': 5}, user_attrs={'num_topics': 11}, system_attrs={}, intermediate_values={}, distributions={'n_neighbors': IntDistribution(high=100, log=False, low=2, step=1), 'min_dist': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_cluster_size': IntDistribution(high=100, log=False, low=5, step=1), 'min_samples': IntDistribution(high=100, log=False, low=5, step=1)}, trial_id=7377, value=None)
